# %% [markdown]
# # Checking the installs for the original SOS jupyter notebook
# I only need R and python so those are the only programs I will check.

# %%
# Let's check the R version (should be 3.4.1)
R.Version()$version.string
# Out:
# [1] "R version 3.4.1 (2017-06-30)"

# %%
# Let's check that python v. 3.6+ works
print("hello world")
# Out:
# hello world

# %%
# Here is a list of library/package versions installed for this notebook
conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _r-mutex                  1.0.0               anacondar_1    defaults
# alembic                   0.9.9                      py_0    conda-forge
# arrow-cpp                 0.10.0           py36h70250a7_0    conda-forge
# asn1crypto                0.24.0                py36_1003    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrs                     18.2.0                     py_0    conda-forge
# attrs                     18.2.0                    <pip>
# backcall                  0.1.0                      py_0    conda-forge
# bash_kernel               0.7.1                     <pip>
# beautifulsoup4            4.6.3                 py36_1000    conda-forge
# blas                      1.1                    openblas    conda-forge
# bleach                    3.0.2                      py_1    conda-forge
# ...
